# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarIvaVP/Importar-datos-PYTHON/blob/main/4%20formas%20de%20Importar%20datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTAR DATOS DE TRABAJO**

# %% [markdown]
# **Opción 1. Cargar desde una carpeta de trabajo de drive**

# %%
# Importar la libreria de pandas

import pandas as pd

from google.colab import files

datos = pd.read_excel("/content/drive/MyDrive/Python - Google Colaboratory/Curso - Estadística Industrial/Datos-Práctica/2.Importar datos/poblacion_mundo.xlsx")
datos
# Out:
#      Año   Aruba  Afganistán    Angola  Albania  Andorra  El mundo árabe  \
# 0   1960   54208     8996967   5454938  1608800    13410        92197715
# 1   1961   55434     9169406   5531451  1659800    14378        94724540
# 2   1962   56234     9351442   5608499  1711319    15379        97334438
# 3   1963   56699     9543200   5679409  1762621    16407       100034191
# 4   1964   57029     9744772   5734995  1814135    17466       102832792
# ..   ...     ...         ...       ...      ...      ...             ...
# 57  2017  105361    36296111  29816769  2873457    76997       411942825
# 58  2018  105846    37171922  30809787  2866376    77008       419851989
# 59  2019  106310    38041757  31825299  2854191    77146       427870273
# 60  2020  106766    38928341  32866268  2837849    77265       436080728
# 61  2021  107195    39835428  33933611  2811666    77354       444517783
#
#     Emiratos Árabes Unidos  Argentina  Armenia  ...  Islas Vírgenes (EE.UU.)  \
# ...

# %% [markdown]
# **Opción 2. Cargar desde computador**

# %%
# Importar la libreria de pandas

import pandas as pd

from google.colab import files
files.upload()

datos1 = pd.read_excel("poblacion_mundo.xlsx")
datos1
# Out:
#      <input type="file" id="files-4757c508-637a-48f5-8953-bd90dea3952f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4757c508-637a-48f5-8953-bd90dea3952f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Opción 3. desde una dirección de drive**

# %%
# Importar la libreria de pandas

import pandas as pd

datos2 = pd.read_excel("https://docs.google.com/spreadsheets/d/e/2PACX-1vTUW9RnO8ijqTNl7WOEvIdbHg354wNVR-_8N3HLTgytkSCBkgXiWuIme4OLWWicFw/pub?output=xlsx")
datos2
# Out:
#      Año   Aruba  Afganistán    Angola  Albania  Andorra  El mundo árabe  \
# 0   1960   54208     8996967   5454938  1608800    13410        92197715
# 1   1961   55434     9169406   5531451  1659800    14378        94724540
# 2   1962   56234     9351442   5608499  1711319    15379        97334438
# 3   1963   56699     9543200   5679409  1762621    16407       100034191
# 4   1964   57029     9744772   5734995  1814135    17466       102832792
# ..   ...     ...         ...       ...      ...      ...             ...
# 57  2017  105361    36296111  29816769  2873457    76997       411942825
# 58  2018  105846    37171922  30809787  2866376    77008       419851989
# 59  2019  106310    38041757  31825299  2854191    77146       427870273
# 60  2020  106766    38928341  32866268  2837849    77265       436080728
# 61  2021  107195    39835428  33933611  2811666    77354       444517783
#
#     Emiratos Árabes Unidos  Argentina  Armenia  ...  Islas Vírgenes (EE.UU.)  \
# ...

# %% [markdown]
# **Opción 4. Subir el archivo al directorio de trabajo**

# %%
# Importar la libreria de pandas

import pandas as pd

datos3 = pd.read_excel("poblacion_mundo.xlsx")
datos3
# Out:
#      Año   Aruba  Afganistán    Angola  Albania  Andorra  El mundo árabe  \
# 0   1960   54208     8996967   5454938  1608800    13410        92197715
# 1   1961   55434     9169406   5531451  1659800    14378        94724540
# 2   1962   56234     9351442   5608499  1711319    15379        97334438
# 3   1963   56699     9543200   5679409  1762621    16407       100034191
# 4   1964   57029     9744772   5734995  1814135    17466       102832792
# ..   ...     ...         ...       ...      ...      ...             ...
# 57  2017  105361    36296111  29816769  2873457    76997       411942825
# 58  2018  105846    37171922  30809787  2866376    77008       419851989
# 59  2019  106310    38041757  31825299  2854191    77146       427870273
# 60  2020  106766    38928341  32866268  2837849    77265       436080728
# 61  2021  107195    39835428  33933611  2811666    77354       444517783
#
#     Emiratos Árabes Unidos  Argentina  Armenia  ...  Islas Vírgenes (EE.UU.)  \
# ...
